# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalana-Lakshan/Rental-product-recommendation-system-competition/blob/main/Rental_product_recommendation_system_competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rental product recommendation system
